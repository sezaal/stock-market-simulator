# %% [markdown]
# <a href="https://colab.research.google.com/github/sezaal/stock-market-simulator/blob/main/stock_market_simulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing required modules
from random import *
import pickle


#defining function used later for the leaderboard
def sortDict(dict1):
  dict2 = {}
  l1 = []
  for i in dict1.keys():
    l1.append(dict1[i][0])


  l1.sort(reverse = True)
  l2 = l1[:5]


  for i in l2:
    for j in dict1.keys():
      if i == dict1[j][0]:
        dict2[j] = dict1[j]
  return dict2


#rules
rules = "Welcome to the Stock Market. You will start off with Rs. 100000, you can use this money to buy and sell shares of different companies. There will be a total of 5 trading sessions at the end of which your final net worth will be calculated. News will help you before each session, so that you can make a profit.\n"
print(rules)


#menu
menu = "1. Price List.\n2. News.\n3. Inventory.\n4. Change day\n5. Info\n6. Trade Center\n7. Exit"


#companies list
companies_list = ['Ishoor', 'Somedo', 'Shok Industries', 'Arkstar', 'Windnayak', 'Kalankar', 'Laman Pharma', 'Tungad Hospitals']


#initializing news
news = [
    {
      'Ishoor':'',
      'Somedo':'',
      'Shok Industries':'',
      'Arkstar':'',
      'Windnayak':'',
      'Kalankar':'',
      'Laman Pharma':'',
      'Tungad Hospitals':''


    },
    {
      'Ishoor':'',
      'Somedo':'',
      'Shok Industries':'',
      'Arkstar':'',
      'Windnayak':'',
      'Kalankar':'',
      'Laman Pharma':'',
      'Tungad Hospitals':''


    },
    {
      'Ishoor':'',
      'Somedo':'',
      'Shok Industries':'',
      'Arkstar':'',
      'Windnayak':'',
      'Kalankar':'',
      'Laman Pharma':'',
      'Tungad Hospitals':''


    },
    {
      'Ishoor':'',
      'Somedo':'',
      'Shok Industries':'',
      'Arkstar':'',
      'Windnayak':'',
      'Kalankar':'',
      'Laman Pharma':'',
      'Tungad Hospitals':''


    },
    {
      'Ishoor':'',
      'Somedo':'',
      'Shok Industries':'',
      'Arkstar':'',
      'Windnayak':'',
      'Kalankar':'',
      'Laman Pharma':'',
      'Tungad Hospitals':''


    }




]


#initializing variables and price list
i = 0
inhand_amount = 100000
day = 0
price_list = [
    {
      'Ishoor':randint(20, 200),
      'Somedo':randint(20, 200),
      'Shok Industries':randint(20, 200),
      'Arkstar':randint(20, 200),
      'Windnayak':randint(20, 200),
      'Kalankar':randint(20, 200),
      'Laman Pharma':randint(20, 200),
      'Tungad Hospitals':randint(20, 200)


    },
    {
      'Ishoor':randint(20, 200),
      'Somedo':randint(20, 200),
      'Shok Industries':randint(20, 200),
      'Arkstar':randint(20, 200),
      'Windnayak':randint(20, 200),
      'Kalankar':randint(20, 200),
      'Laman Pharma':randint(20, 200),
      'Tungad Hospitals':randint(20, 200)


    },
    {
      'Ishoor':randint(20, 200),
      'Somedo':randint(20, 200),
      'Shok Industries':randint(20, 200),
      'Arkstar':randint(20, 200),
      'Windnayak':randint(20, 200),
      'Kalankar':randint(20, 200),
      'Laman Pharma':randint(20, 200),
      'Tungad Hospitals':randint(20, 200)


    },
    {
      'Ishoor':randint(20, 200),
      'Somedo':randint(20, 200),
      'Shok Industries':randint(20, 200),
      'Arkstar':randint(20, 200),
      'Windnayak':randint(20, 200),
      'Kalankar':randint(20, 200),
      'Laman Pharma':randint(20, 200),
      'Tungad Hospitals':randint(20, 200)


    },
    {
      'Ishoor':randint(20, 200),
      'Somedo':randint(20, 200),
      'Shok Industries':randint(20, 200),
      'Arkstar':randint(20, 200),
      'Windnayak':randint(20, 200),
      'Kalankar':randint(20, 200),
      'Laman Pharma':randint(20, 200),
      'Tungad Hospitals':randint(20, 200)


    },
    {
      'Ishoor':randint(20, 200),
      'Somedo':randint(20, 200),
      'Shok Industries':randint(20, 200),
      'Arkstar':randint(20, 200),
      'Windnayak':randint(20, 200),
      'Kalankar':randint(20, 200),
      'Laman Pharma':randint(20, 200),
      'Tungad Hospitals':randint(20, 200)


    }
  ]


#news matrix
negative_news = [
  "Financial results are bad.", "Bad decisions have been made.", "Hint of disapproval of new leadership among employees.", "Rumours of an undervalued acquisition.", "Analysts are expecting prices to go down", "CEO has resigned."
  ]


positive_news = [
  "Financial results are good.", "Smart decisions have been made.", "Hint of approval of new leadership among employees.", "Rumours of an overvalued acquisition.", "Analysts are expecting prices to go up", "New experienced CEO has been signed."
  ]


#decider whether news should be positive or negative
for i in range(0, 5):
  if price_list[i]['Ishoor'] <= price_list[i+1]['Ishoor']:
    news[i]['Ishoor'] = positive_news[randint(0, 5)]

  else:
    news[i]['Ishoor'] = negative_news[randint(0,5)]


  if price_list[i]['Somedo'] <= price_list[i+1]['Somedo']:
    news[i]['Somedo'] = positive_news[randint(0, 5)]

  else:
    news[i]['Somedo'] = negative_news[randint(0,5)]


  if price_list[i]['Somedo'] <= price_list[i+1]['Somedo']:
    news[i]['Somedo'] = positive_news[randint(0, 5)]

  else:
    news[i]['Somedo'] = negative_news[randint(0,5)]


  if price_list[i]['Shok Industries'] <= price_list[i+1]['Shok Industries']:
    news[i]['Shok Industries'] = positive_news[randint(0, 5)]

  else:
    news[i]['Shok Industries'] = negative_news[randint(0,5)]


  if price_list[i]['Arkstar'] <= price_list[i+1]['Arkstar']:
    news[i]['Arkstar'] = positive_news[randint(0, 5)]

  else:
    news[i]['Arkstar'] = negative_news[randint(0,5)]


  if price_list[i]['Windnayak'] <= price_list[i+1]['Windnayak']:
    news[i]['Windnayak'] = positive_news[randint(0, 5)]

  else:
    news[i]['Windnayak'] = negative_news[randint(0,5)]


  if price_list[i]['Kalankar'] <= price_list[i+1]['Kalankar']:
    news[i]['Kalankar'] = positive_news[randint(0, 5)]

  else:
    news[i]['Kalankar'] = negative_news[randint(0,5)]


  if price_list[i]['Laman Pharma'] <= price_list[i+1]['Laman Pharma']:
    news[i]['Laman Pharma'] = positive_news[randint(0, 5)]

  else:
    news[i]['Laman Pharma'] = negative_news[randint(0,5)]


  if price_list[i]['Tungad Hospitals'] <= price_list[i+1]['Tungad Hospitals']:
    news[i]['Tungad Hospitals'] = positive_news[randint(0, 5)]

  else:
    news[i]['Tungad Hospitals'] = negative_news[randint(0,5)]

#intializing inventory
inventory = {
      'Ishoor':0,
      'Somedo':0,
      'Shok Industries':0,
      'Arkstar':0,
      'Windnayak':0,
      'Kalankar':0,
      'Laman Pharma':0,
      'Tungad Hospitals':0


  }


#tradecenter menu
tradecenter_menu = '1. Transaction Window.\n2. Exit trade center.'


#game code
while True:
  if day > 4:
    break
  print('Day: ', day+1, '\n')
  print("You have: ", inhand_amount, "left")
  print(menu)
  choice = int(input())
  if choice == 1:
    print("Ishoor: ", price_list[day]['Ishoor'])
    print("Somedo: ", price_list[day]['Somedo'])
    print("Shok Industries: ", price_list[day]['Shok Industries'])
    print("Arkstar: ", price_list[day]['Arkstar'])
    print("Windnayak: ", price_list[day]['Windnayak'])
    print("Kalankar: ", price_list[day]['Kalankar'])
    print("Laman Pharma: ", price_list[day]['Laman Pharma'])
    print("Tungad Hospitals: ", price_list[day]['Tungad Hospitals'], "\n")


  elif (choice == 2):
    print("Ishoor: ", news[day]['Ishoor'])
    print("Somedo: ", news[day]['Somedo'])
    print("Shok Industries: ", news[day]['Shok Industries'])
    print("Arkstar: ", news[day]['Arkstar'])
    print("Windnayak: ", news[day]['Windnayak'])
    print("Kalankar: ", news[day]['Kalankar'])
    print("Laman Pharma: ", news[day]['Laman Pharma'])
    print("Tungad Hospitals: ", news[day]['Tungad Hospitals'], "\n")


  elif (choice == 3):
    print("Ishoor: ", inventory['Ishoor'])
    print("Somedo: ", inventory['Somedo'])
    print("Shok Industries: ", inventory['Shok Industries'])
    print("Arkstar: ", inventory['Arkstar'])
    print("Windnayak: ", inventory['Windnayak'])
    print("Kalankar: ", inventory['Kalankar'])
    print("Laman Pharma: ", inventory['Laman Pharma'])
    print("Tungad Hospitals: ", inventory['Tungad Hospitals'], "\n")


  elif (choice == 4):
    print("Day changed\n")
    day += 1


  elif (choice == 5):
    print(rules)


  elif (choice == 6):
    while True:


      print(tradecenter_menu)
      choice2 = int(input())


      if choice2 == 1:
        print("Please enter the name of the company.")
        company_trade = str(input())
        if company_trade in companies_list:
          print("Please Enter the quantity")
          trade_quantity = int(input())
          trade_value = price_list[day][company_trade]*trade_quantity
          if trade_value <= inhand_amount:
            inhand_amount = inhand_amount - trade_value
            inventory[company_trade] += trade_quantity
            print("Trade successful.\nYour updated amount: ", inhand_amount)


          else:
            print("Not enough money, transaction failed.")


        else:
          print("Wrong name, please try again.\n")


      elif choice2 == 2:
        break
      else:
        print("Wrong number entered, please try again.")


  elif (choice == 7):
    print("Are you sure? (Y/N)")
    sure = str(input())
    if sure == 'Y':
      break


  else:
    print("Wrong number entered, try again.")


#final score calculation
final_amount = inhand_amount + (inventory['Ishoor']*price_list[5]['Ishoor']) + (inventory['Shok Industries']*price_list[5]['Shok Industries']) + (inventory['Somedo']*price_list[5]['Somedo']) + (inventory['Arkstar']*price_list[5]['Arkstar']) + (inventory['Windnayak']*price_list[5]['Windnayak']) + (inventory['Kalankar']*price_list[5]['Kalankar']) + (inventory['Laman Pharma']*price_list[5]['Laman Pharma']) + (inventory['Tungad Hospitals']*price_list[5]['Tungad Hospitals'])
profit_perc = (final_amount - 100000)/1000


#adding current score to leaderboard
with open("Leaderboard.dat", "ab") as f:
  name = input("Enter name: ")
  dict_dump = {name: [final_amount, profit_perc]}
  pickle.dump(dict_dump, f)


#initializing output of leaderboard
dict_load = {}


#making leaderboard ready to print
with open("Leaderboard.dat", "rb") as f:
  while True:
    try:
      dict_temp = pickle.load(f)
      dict_load.update(dict_temp)
    except:
      break
  dict_print = sortDict(dict_load)


#end of game outputs
print("Thanks for playing.")
print("Your final net worth is: ", final_amount)
print("You made a profit of: ", profit_perc, "%")


#printing leaderboard
print("The following are the current leaders: ")
for i in dict_print.keys():
  print("Name: " + i, end = ' ')
  print("Final Amount: " + str(dict_print[i][0]), end = ' ')
  print("Profit Percentage: " + str(dict_print[i][1]))
# Out:
# Welcome to the Stock Market. You will start off with Rs. 100000, you can use this money to buy and sell shares of different companies. There will be a total of 5 trading sessions at the end of which your final net worth will be calculated. News will help you before each session, so that you can make a profit.
#
# Day:  1
#
# You have:  100000 left
# 1. Price List.
# 2. News.
# 3. Inventory.
# 4. Change day
# 5. Info
# 6. Trade Center
# 7. Exit
# 6
# 1. Transaction Window.
# 2. Exit trade center.
# 1
# Please enter the name of the company.
# Ishoor
# Please Enter the quantity
# 25
# Trade successful.
# Your updated amount:  99200
# 1. Transaction Window.
# 2. Exit trade center.
# 2
# Day:  1
#
# You have:  99200 left
# 1. Price List.
# 2. News.
# 3. Inventory.
# 4. Change day
# 5. Info
# 6. Trade Center
# 7. Exit
# 1
# Ishoor:  32
# Somedo:  142
# Shok Industries:  67
# Arkstar:  54
# Windnayak:  181
# Kalankar:  136
# Laman Pharma:  72
# Tungad Hospitals:  146
#
# Day:  1
#
# ...
